# %%
filename  = 'run.py'
recommendations =[3,10,30]
for nor in recommendations :
    args =[False,nor,2,17]  # train data , number of recommendations, start week, wnd week
    # %run run.py {args[0]} {args[1]} {args[2]} {args[3]}
# Out:
# Recommendation Started
# /home/awanish/Desktop/AWT_Project/AWT-TimeAware-RecommenderSystem/TimeAwareRecommendation.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   Rating_dict[(similarilty_student.dot(df_weight.T)) / similarilty_student.sum()] = not_done[k]  # Rating with Weight
# Recommendation Ended
# _____________________________________________________________________________________
# Accuracy calculation Started
# -------------------------------------
#    WeekNumber TrainedStudents TrainedTopics TestedStudents TestedTopics  \
# 0           2              22            25             94           89
# 1           3              44            50             88           89
# 2           4              55            56             84           89
# 3           5              58            57             83           88
# 4           6              64            58             80           88
# ...

# %%
filename  = 'run.py'
recommendations =[3,10,30]
for nor in recommendations :
    args =[False,nor,2,17]  # train data , number of recommendations, start week, wnd week
    # %run run.py {args[0]} {args[1]} {args[2]} {args[3]}
# Out:
# Recommendation Started
# /home/awanish/Desktop/AWT_Project/AWT-TimeAware-RecommenderSystem/TimeAwareRecommendation.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   Rating_dict[(similarilty_student.dot(df_weight.T)) / similarilty_student.sum()] = not_done[k]  # Rating with Weight
# Recommendation Ended
# _____________________________________________________________________________________
# Accuracy calculation Started
# -------------------------------------
#    WeekNumber TrainedStudents TrainedTopics TestedStudents TestedTopics  \
# 0           2              22            25             94           89
# 1           3              44            50             88           89
# 2           4              55            56             84           89
# 3           5              58            57             83           88
# 4           6              64            58             80           88
# ...

# %%
filename  = 'run.py'
recommendations =[3]
for nor in recommendations :
    args =[False,nor,2,17]  # train data , number of recommendations, start week, end weeks
    # %run run.py {args[0]} {args[1]} {args[2]} {args[3]}
# Out:
# Recommendation Started
# Recommendation Ended
# _____________________________________________________________________________________
# Accuracy calculation Started
# -------------------------------------
#    WeekNumber TrainedStudents TrainedTopics TestedStudents TestedTopics  \
# 0           2              22            25             94           89
# 1           3              44            50             88           89
# 2           4              55            56             84           89
# 3           5              58            57             83           88
# 4           6              64            58             80           88
# 5           7              70            67             79           88
# 6           8              72            72             79           88
# 7           9              73            80             78           88
# 8          10              74            80             78           88
# ...

# %%
print('rated users')
filename  = 'run.py'
recommendations =[3]
for nor in recommendations :
    args =[True,nor,2,17]  # train data , number of recommendations, start week, wnd week
    # %run run.py {args[0]} {args[1]} {args[2]} {args[3]}
# Out:
# rated users
# Training Started
# week 1
# INFO:similaritymatrix:Starting calculation....
# INFO:similaritymatrix:['LO_0', 'LO_1', 'LO_10', 'LO_11', 'LO_12', 'LO_13', 'LO_14', 'LO_15', 'LO_16', 'LO_17', 'LO_18', 'LO_19', 'LO_2', 'LO_20', 'LO_21', 'LO_22', 'LO_23', 'LO_24', 'LO_3', 'LO_4', 'LO_5', 'LO_6', 'LO_7', 'LO_8', 'LO_9']
# LOM done
# LOM Mapping done
# INFO:similaritymatrix:LO_0
# timeTaken:  0:00:00.229698
# INFO:similaritymatrix:Finish calculation
# timeTaken:  0:00:03.033532
# Similarity done
# Similarity Mapping done
# trained week 1
# week 2
# INFO:similaritymatrix:Starting calculation....
# ...

# %%
print('rated users, Accuracy')
filename  = 'run.py'
recommendations =[3,10,30]
for nor in recommendations :
    args =[False,nor,2,17]  # train data , number of recommendations, start week, wnd week
    # %run run.py {args[0]} {args[1]} {args[2]} {args[3]}
# Out:
# rated users, Accuracy
# Recommendation Started
# /home/awanish/Desktop/AWT_Project/AWT-TimeAware-RecommenderSystem/TimeAwareRecommendation.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   Rating_dict[(similarilty_student.dot(df_weight.T)) / similarilty_student.sum()] = not_done[k]  # Rating with Weight
# Recommendation Ended
# _____________________________________________________________________________________
# Accuracy calculation Started
# -------------------------------------
#    WeekNumber TrainedStudents TrainedTopics TestedStudents TestedTopics  \
# 0           2              22            25             94           89
# 1           3              44            50             88           89
# 2           4              55            56             84           89
# 3           5              58            57             83           88
# 4           6              64            58             80           88
# ...

# %%
print('rated users, Accuracy')
filename  = 'run.py'
recommendations =[30]
for nor in recommendations :
    args =[False,nor,2,17]  # train data , number of recommendations, start week, wnd week
    # %run run.py {args[0]} {args[1]} {args[2]} {args[3]}
# Out:
# rated users, Accuracy
# Recommendation Started
# /home/awanish/Desktop/AWT_Project/AWT-TimeAware-RecommenderSystem/TimeAwareRecommendation.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   Rating_dict[(similarilty_student.dot(df_weight.T)) / similarilty_student.sum()] = not_done[k]  # Rating with Weight
# Recommendation Ended
# _____________________________________________________________________________________
# Accuracy calculation Started
# -------------------------------------
#    WeekNumber TrainedStudents TrainedTopics TestedStudents TestedTopics  \
# 0           2              22            25             94           89
# 1           3              44            50             88           89
# 2           4              55            56             84           89
# 3           5              58            57             83           88
# 4           6              64            58             80           88
# ...

# %%
print('rated users, Accuracy')
filename  = 'run.py'
recommendations =[3]
for nor in recommendations :
    args =[False,nor,2,17]  # train data , number of recommendations, start week, wnd week
    # %run run.py {args[0]} {args[1]} {args[2]} {args[3]}
# Out:
# rated users, Accuracy
# Recommendation Started
# Recommendation Ended
# _____________________________________________________________________________________
# Accuracy calculation Started
# student092@smartlearning.edu
# 2
# student008@smartlearning.edu
# 3
# student019@smartlearning.edu
# 3
# student028@smartlearning.edu
# 3
# student043@smartlearning.edu
# 3
# student090@smartlearning.edu
# 3
# student092@smartlearning.edu
# 3
# student042@smartlearning.edu
# 3
# student008@smartlearning.edu
# 4
# student019@smartlearning.edu
# 4
# student003@smartlearning.edu
# 4
# student070@smartlearning.edu
# 4
# student028@smartlearning.edu
# 4
# student096@smartlearning.edu
# 4
# student043@smartlearning.edu
# 4
# student090@smartlearning.edu
# 4
# student092@smartlearning.edu
# 4
# student069@smartlearning.edu
# 4
# student042@smartlearning.edu
# 4
# student008@smartlearning.edu
# 5
# student019@smartlearning.edu
# 5
# student003@smartlearning.edu
# 5
# student070@smartlearning.edu
# 5
# ...

# %%
print('rated users')
filename  = 'run.py'
recommendations =[3,10,30]
for nor in recommendations :
    args =[False,nor,2,17]  # train data , number of recommendations, start week, wnd week
    # %run run.py {args[0]} {args[1]} {args[2]} {args[3]}
# Out:
# rated users
# Recommendation Started
# /media/rudresh/Media/Academic/AWT_Project/SourceCode/AWT-TimeAware-RecommenderSystem/TimeAwareRecommendation.py:48: RuntimeWarning: invalid value encountered in double_scalars
#   Rating_dict[(similarilty_student.dot(df_weight.T)) / similarilty_student.sum()] = not_done[k]  # Rating with Weight
# Recommendation Ended
# _____________________________________________________________________________________
# Accuracy calculation Started
# -------------------------------------
#    WeekNumber TrainedStudents TrainedTopics TestedStudents TestedTopics  \
# 0           2              22            25             94           89
# 1           3              44            50             88           89
# 2           4              55            56             84           89
# 3           5              58            57             83           88
# 4           6              64            58             80           88
# ...
